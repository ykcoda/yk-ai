# %%
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # OpenAI Model

# %%
from langchain.chat_models import init_chat_model
models = init_chat_model("gpt-5-nano")
models
# Out:
# ChatOpenAI(profile={'max_input_tokens': 272000, 'max_output_tokens': 128000, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x108960590>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x108961970>, root_client=<openai.OpenAI object at 0x1089603e0>, root_async_client=<openai.AsyncOpenAI object at 0x108960c20>, model_name='gpt-5-nano', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)

# %%
##Invoke the model
response = models.invoke("Hello how are you?")
response.content
# Out:
# 'Hi! I’m here and ready to help. I don’t have feelings, but I’m functioning well. How about you? What would you like to do today—ask a question, brainstorm ideas, get help with something, or just chat?'

# %% [markdown]
# #  Google Gemini Model

# %%
from langchain.chat_models import init_chat_model

models = init_chat_model("google_genai:gemini-2.5-flash-lite")
response = models.invoke("Why do parots talk?")
response.content
# Out:
# 'Parrots talk for a variety of fascinating reasons, and it\'s a complex behavior that involves both biological predispositions and social learning. Here\'s a breakdown of the main drivers:\n\n**1. Social Bonding and Communication within the Flock:**\n\n* **Mimicry as a Social Tool:** In the wild, parrots live in highly social flocks. They use vocalizations extensively for communication within the group. Mimicry is a crucial part of this. By imitating the sounds of their flock mates, they can:\n    * **Maintain Contact:** Keep track of each other in dense foliage or when flying.\n    * **Strengthen Bonds:** Develop a shared "dialect" or repertoire of calls within a specific flock, fostering a sense of belonging.\n    * **Signal Danger:** Alarm calls are vital for survival.\n    * **Coordinate Activities:** Communicate about food sources or locations.\n* **Learning the "Language" of the Flock:** Young parrots learn the specific calls and vocalizations of their parents and other flock m
# ...

# %% [markdown]
# # Using Chat_OpenAI

# %%
from langchain_openai import ChatOpenAI
models = ChatOpenAI(model="gpt-5")
(models.invoke("hello how are you?")).content
# Out:
# 'Hi! I’m doing well, thanks for asking. How can I help you today?'
