# %% [markdown]
# ### Messages

# %%
from dotenv import load_dotenv
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model


load_dotenv()

model = init_chat_model("gpt-5")
model.invoke("What is the capital of ghana")
# Out:
# AIMessage(content='Accra.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 76, 'prompt_tokens': 13, 'total_tokens': 89, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DBITkYD6RJiyLC6tB48f18AndZk6T', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c7ab2-004a-78a0-8586-46edabf3b503-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 76, 'total_tokens': 89, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}})

# %% [markdown]
# ### System Message

# %%
from langchain.messages import HumanMessage, SystemMessage, AIMessage

messages = [
    SystemMessage("You are a football expect"),
    HumanMessage("Who do you think will win the english premier league?")
]

response = model.invoke(messages)

response.content
# Out:
# 'Short answer: Manchester City.\n\nReasoning:\n- They’ve had the deepest, most flexible squad and the most consistent underlying metrics for years, and they’re the only Premier League side that reliably sustains 85–90+ point paces with long winning runs.\n- Arsenal look the most credible challengers (elite defense, rising core). Liverpool are in the mix but are still a bit more variable post-Klopp.\n- Outsiders with a puncher’s chance: Tottenham, Manchester United, Chelsea, Newcastle, Aston Villa.\n\nVery rough preseason-style probabilities without current standings:\n- Man City: ~45–55%\n- Arsenal: ~20–30%\n- Liverpool: ~10–20%\n- Others combined: ~10–15%\n\nIf you share the current table or key injuries, I’ll refine the pick.'

# %%
human_msg = HumanMessage(content="Hello", name="Yaw", id="msg_123")

model.invoke([human_msg])
# Out:
# AIMessage(content='Hello! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 338, 'prompt_tokens': 9, 'total_tokens': 347, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DBLSnWQTmWmQWqgZlO9ToSDLMXpcQ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c7b61-0f29-7e93-91f9-c62bd7696773-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 338, 'total_tokens': 347, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}})
